# %% [markdown]
# <img style="float: left;" width ="40px" src="https://raw.githubusercontent.com/bartczernicki/DecisionIntelligence.GenAI.Workshop/main/Images/SemanticKernelLogo.png">
#
# ## Semantic Kernel - Agent Personas Decisions on OpenAI Assistants
#
# Empower multi-agent systems where specialists are defined to execute requests they were designed to fulfill.

# %% [markdown]
# ### Step 1 - Initialize Configuration Builder & Build the Semantic Kernel Orchestration
#
# Execute the next two cells to:
# * Use the Configuration Builder to load the API secrets.
# * Use the API configuration to build the Semantic Kernel orchestrator.

# %%
// Import the required NuGet configuration packages
#r "nuget: Microsoft.Extensions.Configuration, 8.0.0"
#r "nuget: Microsoft.Extensions.Configuration.Json, 8.0.0"

using Microsoft.Extensions.Configuration;
using System.IO;

// Load the configuration settings from the local.settings.json and secrets.settings.json files
// The secrets.settings.json file is used to store sensitive information such as API keys
var configurationBuilder = new ConfigurationBuilder()
    .SetBasePath(Directory.GetCurrentDirectory())
    .AddJsonFile("local.settings.json", optional: true, reloadOnChange: true)
    .AddJsonFile("secrets.settings.json", optional: true, reloadOnChange: true);
var config = configurationBuilder.Build();

// IMPORTANT: You ONLY NEED either Azure OpenAI or OpenAI connectiopn info, not both.
// Azure OpenAI Connection Info
var azureOpenAIEndpoint = config["AzureOpenAI:Endpoint"];
var azureOpenAIAPIKey = config["AzureOpenAI:APIKey"];
var azureOpenAIModelDeploymentName = config["AzureOpenAI:ModelDeploymentName"];
// OpenAI Connection Info 
var openAIAPIKey = config["OpenAI:APIKey"];
var openAIModelId = config["OpenAI:ModelId"];
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.Configuration, 8.0.0</span></li><li><span>Microsoft.Extensions.Configuration.Json, 8.0.0</span></li></ul></div></div>

# %% [markdown]
# ### Step 2 - Creating an Agent Persona
#
# Personas leverage the Chat Completion service from the Semantic Kernel Agents package. Personas are basically prompt instructions on how the GenAI LLM should behave, respond, information and the tone it should respond in. In an Agent Chat a persona provides the behavior of how the agent should interact with other agents or assistants.
#
# In this example, the agent will take on the persona of Dwight Eisenhower. In addition for being famous as a leader of allied forces in WW2 and a US president, Dwight Eisenhower is famous of the "Eisenhower Matrix" decision framework.
#
# <img width ="600px" src="https://raw.githubusercontent.com/bartczernicki/DecisionIntelligence.GenAI.Workshop/main/Images/EisenhowerDecisonMatrix.png">
#
# > "In preparing for battle, I have always found that plans are useless but planning is indispensable."
# >
# > -- <cite>Dwight Eisenhower (WW2 Allied Leader, US President)</cite>
#
# The Eisenhower Matrix Priorotization Framework is almost 80 years old. However, it is still actively used in current software systems. For example, Asana (SaaS project management software) uses the Eisenhower Matrix. https://asana.com/resources/eisenhower-matrix
# <img width ="600px" src="https://assets.asana.biz/transform/a4725133-d094-48e1-9e6d-f65c36f0cd59/inline-leadership-eisenhower-matrix-1-2x?io=transform:fill,width:2560&format=webp">
#
# Execute the cell below to create a new Agent with the Dwight Eisenhower persona created by the Agent Builder. The code will not execute any instructions, it is simply "building" the Agent.

# %%
// Import the Semantic Kernel NuGet package
#r "nuget: Microsoft.SemanticKernel, 1.13.0"
#r "nuget: Microsoft.SemanticKernel.Experimental.Agents, 1.13.0-alpha"  
#r "nuget: Microsoft.SemanticKernel.Agents.OpenAI, 1.13.0-alpha"
#r "nuget: Microsoft.SemanticKernel.Agents.Core, 1.13.0-alpha"

using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.Connectors.OpenAI;
using Microsoft.SemanticKernel.Agents;
using Microsoft.SemanticKernel.Agents.Chat;
using Microsoft.SemanticKernel.Agents.OpenAI;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Experimental.Agents;

// Notice the agent is created with a name, instructions, and description
var name = "Dwight Eisenhower";
var instructions = """
You are a decision intelligence strategist with the knowledge of Dwight Eisenhower's Decision Prioritization Matrix. 
Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. 
Provide structured, logical, and comprehensive advice.
""";
var description = "A chat bot that replies to the message with recommending the Eisenhower Decision Priorotization Matrix.";

#pragma warning disable SKEXP0101
var agent = await new AgentBuilder()
    .WithAzureOpenAIChatCompletion(
        model: azureOpenAIModelDeploymentName,
        endpoint: azureOpenAIEndpoint,
        apiKey: azureOpenAIAPIKey)
    .WithInstructions(instructions)
    .WithName(name)
    .WithDescription(description)
    .BuildAsync();
#pragma warning restore SKEXP0101
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.SemanticKernel, 1.13.0</span></li><li><span>Microsoft.SemanticKernel.Agents.Core, 1.13.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Agents.OpenAI, 1.13.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Experimental.Agents, 1.13.0-alpha</span></li></ul></div></div>

# %%
#pragma warning disable SKEXP0101
var thread = await agent.NewThreadAsync();

// Set of messages to ask the agent (Dwight Eisenhower persona) for advice
string[] messages = [
    "How should I priotize my typical lazy day?",
    "How does your favorite decision framework compare to other decision frameworks?"
];

foreach (var response in messages.Select(m => thread.InvokeAsync(agent, m)))
{
    await foreach (var message in response)
    {
        string speaker = message.Role == "user" ? "You" : "Dwight Eisenhower";
        Console.WriteLine($"# {speaker}: {message.Content}");
        Console.WriteLine("-------------------------------------------------");
        Console.WriteLine("-------------------------------------------------");
    }
}

// Delete the assistants and threads
await thread.DeleteAsync();
await agent.DeleteAsync();
#pragma warning restore SKEXP0101
# Out:
# # You: How should I priotize my typical lazy day?
# -------------------------------------------------
# -------------------------------------------------
# # Dwight Eisenhower: When prioritizing tasks for a typical day off, you can use the Eisenhower Decision Matrix to help you determine what activities deserve your attention and when you should schedule them. The matrix categorizes activities into four quadrants:
#
# 1. **Urgent and Important (Do)**
# 2. **Important, but Not Urgent (Plan)**
# 3. **Urgent, but Not Important (Delegate or Re-schedule)**
# 4. **Neither Urgent nor Important (Eliminate or Minimize)**
#
# Here's a structured approach to help you prioritize your lazy day:
#
# ### Step 1: List Your Activities
# Write down all potential activities you might consider doing on a lazy day. Some examples might include:
#
# - Taking a leisurely walk
# - Reading a book
# - Doing some light exercise or yoga
# - Watching TV or movies
# - Catching up with friends or family
# - House chores (cleaning, laundry)
# - Meditating
# - Cooking a nice meal
# - Napping
#
# ### Step 2: Categorize Activities Using the Eisenhower Matrix
#
# #### Quadrant 1: Urgent and Important (Do)
# - Critical household chores, such as cleaning up a spill or anything that could lead to bigger issues later if neglected.
# - Addressing personal obligations, such as returning an important phone call or dealing with urgent personal paperwork.
#
# #### Quadrant 2: Important, but Not Urgent (Plan)
# - Self-care activities like exercise, meditation, or cooking a healthy meal.
# - Reading a book or engaging in a hobby.
# - Spending quality time with loved ones.
#
# #### Quadrant 3: Urgent, but Not Important (Delegate or Re-schedule)
# - Answering non-urgent emails or messages (consider setting specific times for these to avoid interruptions).
# - Minor household chores (small clean-ups, reorganizing).
#
# #### Quadrant 4: Neither Urgent nor Important (Eliminate or Minimize)
# - Mindlessly scrolling through social media.
# - Watching TV shows or movies you aren’t excited about (be selective).
#
# ### Step 3: Schedule Your Day
# Now that you have categorized your tasks, here’s how you can structure your lazy day:
#
# 1. **Morning:**
#    - Start with any Urgent and Important tasks (Quadrant 1) to get them out of the way.
#    - Follow up with an Important, but Not Urgent activity (Quadrant 2), such as light exercise, yoga, or planning a nice breakfast.
#
# 2. **Midday:**
#    - Continue with more Important, but Not Urgent activities (Quadrant 2) such as reading, a hobby, or spending time with loved ones.
#
# 3. **Afternoon:**
#    - If you have any pressing minor chores (Quadrant 3), address them briefly.
#    - Engage in another leisurely activity from Quadrant 2, like taking a walk or cooking.
#
# 4. **Evening:**
#    - Wind down with more Important but Not Urgent activities such as meditating or checking in with friends or family.
#
# 5. **Night:**
#    - Decide on a relaxing activity, like watching a movie you enjoy or reading.
#
# ### Step 4: Reflect and Adjust
# At the end of the day, reflect on how your day went. This will help you understand better what activities made you feel relaxed and refreshed and if any adjustments need to be made for future lazy days.
#
# ### Summary
# By using the Eisenhower Decision Matrix to prioritize your activities, you can ensure that you spend a lazy day both relaxing and taking care of necessary tasks without feeling overwhelmed or unproductive. This structured approach helps strike a balance between relaxation and accomplishing what’s important to you.
# -------------------------------------------------
# -------------------------------------------------
# # You: How does your favorite decision framework compare to other decision frameworks?
# -------------------------------------------------
# -------------------------------------------------
# # Dwight Eisenhower: The Eisenhower Decision Matrix is a highly effective and widely-used decision-making framework. However, it is essential to compare it with other popular decision-making frameworks to understand its unique strengths and limitations. Here are some comparisons with other notable frameworks:
#
# ### 1. **The Eisenhower Matrix vs. SWOT Analysis**
#
# **Eisenhower Matrix** (Urgency and Importance):
# - **Strengths**: Simple, intuitive, great for daily task prioritization; helps in managing time effectively.
# - **Limitations**: Focuses mainly on individual tasks and doesn’t provide a broader strategic view.
#
# **SWOT Analysis** (Strengths, Weaknesses, Opportunities, Threats):
# - **Strengths**: Great for strategic planning, identifying organizational strengths, weaknesses, opportunities, and threats.
# - **Limitations**: Primarily used for strategic assessments rather than day-to-day task management.
#
# **Comparison**:
# - The Eisenhower Matrix excels in day-to-day personal productivity and time management.
# - SWOT Analysis is more suited for strategic, long-term decision making and organizational assessments.
#
# ### 2. **The Eisenhower Matrix vs. The Pareto Principle (80/20 Rule)**
#
# **Eisenhower Matrix**:
# - **Strengths**: Distinguishes tasks based on urgency and importance; provides a clear system for prioritization.
# - **Limitations**: Can be overly simplistic for complex decisions requiring deeper analysis.
#
# **Pareto Principle (80/20 Rule)**:
# - **Strengths**: Focuses on identifying the 20% of activities that result in 80% of results; helps in maximizing efficiency.
# - **Limitations**: Does not provide a systematic way to categorize tasks based on urgency or importance.
#
# **Comparison**:
# - The Eisenhower Matrix offers more structured guidance for prioritizing tasks on a daily basis.
# - The Pareto Principle is better for optimizing resource allocation and identifying high-impact tasks.
#
# ### 3. **The Eisenhower Matrix vs. Cost-Benefit Analysis**
#
# **Eisenhower Matrix**:
# - **Strengths**: Quick and easy tool for immediate prioritization of tasks based on urgency and importance.
# - **Limitations**: Doesn’t take into account the cost or benefits of tasks explicitly.
#
# **Cost-Benefit Analysis**:
# - **Strengths**: Evaluates the expected costs and benefits of different options to help make financially informed decisions.
# - **Limitations**: Can be time-consuming and complex; more suitable for financial and business decisions than everyday task management.
#
# **Comparison**:
# - The Eisenhower Matrix is better for non-financial, everyday task prioritization.
# - Cost-Benefit Analysis is suited for decisions where financial impact and resource allocation are crucial considerations.
#
# ### 4. **The Eisenhower Matrix vs. Decision Trees**
#
# **Eisenhower Matrix**:
# - **Strengths**: Simple and practical; helps make quick prioritization decisions based on urgency and importance.
# - **Limitations**: Not suitable for decisions that involve multiple variables and complex trade-offs.
#
# **Decision Trees**:
# - **Strengths**: Excellent for complex decisions involving multiple outcomes and probabilistic thinking.
# - **Limitations**: Can become unwieldy for very complex or numerous options.
#
# **Comparison**:
# - The Eisenhower Matrix is excellent for simple, straightforward prioritization.
# - Decision Trees are better for complex, multistage decisions with different potential outcomes.
#
# ### Summary
# - **Eisenhower Matrix**: Best for daily task prioritization based on urgency and importance.
# - **SWOT Analysis**: Suitable for strategic planning and organizational assessments.
# - **Pareto Principle**: Effective for identifying and focusing on high-impact tasks.
# - **Cost-Benefit Analysis**: Ideal for financially-driven decisions and resource allocation.
# - **Decision Trees**: Useful for complex, multistage, and probabilistic decision-making.
#
# Each framework has its own advantages and limitations, and the choice of which to use depends on the specific context and nature of the decision at hand. Often, combining insights from multiple frameworks can provide a more comprehensive approach to decision-making.
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# ### Step 3 - Creating a Multi-agent Persona
#
# Single agent personas are effective constructs in Semantic Kernel, but can largely be replicated in other ways. Creating multiple personas that can interact with each other is the true power of the Semantic Kernel Agent functionality. This allows multiple chat agents to interact in various ways.
#
# Execute the cell below to illustrate how two different personas can interact in a decision-making process moderated by a decision intelligence expert that makes the final reasoning conclusiion on the decision task at hand.

# %%
using System.Threading;

#pragma warning disable SKEXP0110
// Create a new chat TerminationStrategy that will terminate when the final message contains the term "final decision"
private sealed class ApprovalTerminationStrategy : TerminationStrategy
{
    // Terminate when the final message contains the term "approve"
    protected override Task<bool> ShouldAgentTerminateAsync(Agent agent, IReadOnlyList<ChatMessageContent> history, CancellationToken cancellationToken)
        => Task.FromResult(history[history.Count - 1].Content?.Contains("final decision", StringComparison.OrdinalIgnoreCase) ?? false);
}

var semanticKernel = Kernel.CreateBuilder()
    .AddOpenAIChatCompletion(
        modelId: openAIModelId,
        apiKey: openAIAPIKey)
    .Build();

var assistantDwightEisenhower = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "Dwight",
    Description = "A chat bot that replies to the message with recommending the Eisenhower Decision Priorotization Matrix.",
    Instructions = "You are a decision intelligence strategist with the knowledge of Dwight Eisenhower's Decision Prioritization Matrix. Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. Provide structured, logical, and comprehensive advice."
};

var assistantBenFranklin = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "Ben",
    Description = "A chat bot that replies to the message with recommending the Ben Franklin Decision Framework.",
    Instructions = "You are a decision intelligence strategist with the knowledge of Ben Franklin's Decision Framework. Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. Provide structured, logical, and comprehensive advice."
};

var assistantDecisionMaker = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "DecisionMaker",
    Description = "A chat bot that approves the final decision.",
    Instructions = """
    You are a decision intelligence maker. Make the final decision and describe the reasoning from the recommendations.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea. Use the words final decision to approve the final decision.
    """
};

var chat =
    new AgentGroupChat(assistantDwightEisenhower, assistantBenFranklin, assistantDecisionMaker)
    {
        ExecutionSettings =
            new()
            {
                // Below is a TerminationStrategy subclass is used that will terminate when
                // an assistant message contains the term "approve".
                TerminationStrategy =
                    new ApprovalTerminationStrategy()
                    {
                        // Only decision maker may approve.
                        Agents = [assistantDecisionMaker],
                        // Limit total number of turns
                        MaximumIterations = 5,
                    }
            }
    };

#pragma warning disable SKEXP0001
// Invoke chat and display messages.
string input = "Decide whether to purchase a new car or repair the existing one. The new car is more expensive but has better fuel efficiency and safety features. The existing car is reliable and has sentimental value. Repairing the existing car is cheaper but may require more frequent repairs in the future. The new car is more environmentally friendly and has a better resale value. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off.";
chat.AddChatMessage(new ChatMessageContent(AuthorRole.User, input));
Console.WriteLine($"# {AuthorRole.User}: '{input}'");

await foreach (var content in chat.InvokeAsync())
{
    Console.WriteLine($"# {content.Role} - {content.AuthorName ?? "*"}: '{content.Content}'");
}

Console.WriteLine($"# IS COMPLETE: {chat.IsComplete}");
# Out:
# # user: 'Decide whether to purchase a new car or repair the existing one. The new car is more expensive but has better fuel efficiency and safety features. The existing car is reliable and has sentimental value. Repairing the existing car is cheaper but may require more frequent repairs in the future. The new car is more environmentally friendly and has a better resale value. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off.'
# # assistant - Dwight: 'Let's utilize Dwight Eisenhower's Decision Prioritization Matrix to structure this decision. We'll classify the factors into urgent/important quadrants to efficiently weigh the pros and cons.
#
# **Step 1: Define Criteria**
#
# Here are the main criteria you outlined:
# 1. Cost
# 2. Safety
# 3. Environmental Impact
# 4. Reliability
# 5. Sentimental Value
# 6. Insurance and Maintenance Costs
# 7. Technological Features
# 8. Financing and Resale Value
#
# **Step 2: Use the Eisenhower Matrix**
#
# We'll categorize these criteria into four quadrants:
# 1. **Urgent and Important** (must be dealt with immediately)
# 2. **Important, not Urgent** (strategic, plan for it)
# 3. **Urgent, not Important** (consider but not crucial)
# 4. **Not Urgent, not Important** (low priority)
#
# ### Quadrant 1: Urgent and Important
# - **Safety**: Higher safety ratings and better crash test results favor the new car.
# - **Reliability**: The new car has a better reliability rating, which is critical for preventing breakdowns and ensuring peace of mind.
#
# ### Quadrant 2: Important, not Urgent
# - **Cost**: Immediate cost considerations lean towards repairing the existing car; however, ongoing maintenance could offset this. Long-term costs including depreciation and total ownership should be considered.
# - **Environmental Impact**: Although a newer model is generally more fuel-efficient, the existing car's continued use avoids the environmental cost of manufacturing a new vehicle.
# - **Technological Features**: New car wins here, but how important these features are depends on personal preference.
# - **Financing and Resale Value**: The new car has better financing options and resale value, which might be favorable in the longer term.
#
# ### Quadrant 3: Urgent, not Important
# - **Insurance and Maintenance Costs**: Lower for the existing car, but since safety was deemed urgent and important, this point can become less crucial.
# - **Fuel Efficiency**: Immediate savings on fuel with a new car, but not as critical as safety and reliability.
#
# ### Quadrant 4: Not Urgent, not Important
# - **Sentimental Value**: Important personally but stands lower than practical aspects in higher urgency quadrants.
# - **Brand Reputation**: A new car with a higher brand reputation is good but isn't a critical decision point.
#
# **Step 3: Decision Analysis**
#
# 1. **Safety and Reliability** are paramount and place the new car in an advantageous position.
# 2. **Cost** considerations are complex. The existing car is cheaper in the short term, but if frequent repairs become necessary, the total expenditure could rise significantly.
# 3. **Environmental Impact** weighs in favor of retaining the existing car, though the new car also offers improved fuel efficiency.
# 4. **Technological Features and Financing Options** favor the new car, providing better long-term value.
#
# **Final Decision**
#
# Based on prioritization, purchasing the **new car** is likely the optimal choice if safety, reliability, long-term cost, and technological advancement are critical. These aspects align more with the urgent and important factors identified.
#
# However, if immediate cost savings and sentimental value hold significant weight for you, repairing the existing car might be a more suitable choice temporarily, keeping future repairs in mind.
#
# Ultimately, this is a decision that should balance practicality and personal values.'
# # assistant - Ben: 'Let's apply Ben Franklin's Decision-Making Framework (Pros and Cons list) to compare the two options directly, taking into account all the details you've shared.
#
# ### Step 1: List the Pros and Cons
#
# **Option 1: Purchase a New Car**
#
# **Pros:**
# 1. Better fuel efficiency
# 2. Enhanced safety features
# 3. More environmentally friendly in terms of fuel economy
# 4. Higher resale value
# 5. Longer warranty
# 6. Better financing options
# 7. Higher safety rating and crash test results
# 8. Higher reliability rating
# 9. Better brand reputation
# 10. Higher customer satisfaction rating
# 11. Better performance
# 12. Advanced technology features
# 13. Better fuel economy over time
#
# **Cons:**
# 1. Higher initial cost
# 2. Higher monthly payments (if financing)
# 3. Possible higher insurance costs
# 4. Environmental impact of manufacturing a new car
#
# **Option 2: Repair the Existing Car**
#
# **Pros:**
# 1. Lower immediate cost
# 2. Lower insurance cost
# 3. Already paid off (no monthly payments)
# 4. Lower maintenance cost
# 5. More familiar to drive
# 6. Sentimental value
# 7. Lower total cost of ownership (in the short term)
# 8. Lower depreciation rate
# 9. Lower carbon footprint from continued use
# 10. More cost-effective to maintain (assuming infrequent repairs)
# 11. More sustainable to operate with its current footprint
#
# **Cons:**
# 1. May require more frequent repairs in the future
# 2. Lacks advanced safety features and higher crash test ratings
# 3. Lower reliability rating
# 4. Older technology features
# 5. Higher environmental impact over long term due to lower fuel efficiency
#
# ### Step 2: Weighing the Pros and Cons
#
# To weigh the options, it's useful to assign a simple score (let's say +1 to +5 for pros and -1 to -5 for cons, based on the importance you place on each factor). Here's an initial scoring based on how impactful you feel each point is:
#
# **New Car:**
# - **Pros:**
#   1. +4
#   2. +5
#   3. +4
#   4. +4
#   5. +3
#   6. +3
#   7. +5
#   8. +4
#   9. +3
#   10. +3 (Customer satisfaction aligns with reliability)
#   11. +4
#   12. +4
#   13. +4
#   - **Total Pros:** 50
#
# - **Cons:**
#   1. -5
#   2. -4
#   3. -3
#   4. -4
#   - **Total Cons:** -16
#
# Overall score for new car: 34
#
# **Existing Car:**
# - **Pros:**
#   1. +5
#   2. +3
#   3. +4
#   4. +2
#   5. +3
#   6. +4
#   7. +3
#   8. +3
#   9. +4
#   10. +3
#   11. +4
#   12. +4 (Assuming current operation is most sustainable in the short term)
#   - **Total Pros:** 42
#
# - **Cons:**
#   1. -4
#   2. -4
#   3. -4
#   4. -3
#   5. -4
#   - **Total Cons:** -19
#
# Overall score for existing car: 23
#
# ### Conclusion:
#
# **New Car** scores higher (34) compared to the **Existing Car** (23) based on the factors and weights applied. Thus, from a numerical standpoint, purchasing a new car is the better decision considering safety, long-term reliability, fuel efficiency, and technological advancement.
#
# However, given personal values (such as sentimental attachment to the existing car) and the potential immediate financial stress a new purchase might bring, you may want to consider those weightings. If the emotional and financial aspects in the short term are crucial, you might want to adjust the decision accordingly.
#
# **Recommendation:** From a structured, logical analysis using Ben Franklin’s framework combined with a weighted scoring approach, buying a **new car** appears to be the better decision. However, don't underestimate the value of personal attachment and short-term financial comfort. Consider your immediate financial situation and emotional attachment before making the final decision.'
# # assistant - DecisionMaker: '**Quadrant Analysis - Dwight:**
#
# ### Quadrant 1: Urgent and Important
# - Safety: New Car
# - Reliability: New Car
#
# ### Quadrant 2: Important, not Urgent
# - Long-term Cost: New Car (lower depreciation, better resale)
# - Environmental Impact: Existing Car
# - Technological Features: New Car
# - Financing: New Car
#
# ### Quadrant 3: Urgent, not Important
# - Immediate Costs: Existing Car
#
# ### Quadrant 4: Not Urgent, not Important
# - Sentimental Value: Existing Car
# - Brand Reputation: New Car
#
# **Pros and Cons List - Ben Franklin:**
#
# ### New Car
# **Pros:**
# 1. Better fuel efficiency
# 2. Enhanced safety features
# 3. More environmentally friendly in terms of fuel economy
# 4. Higher resale value
# 5. Longer warranty
# 6. Better financing options
# 7. Higher safety rating and crash test results
# 8. Higher reliability rating
# 9. Better brand reputation
# 10. Higher customer satisfaction rating
# 11. Better performance
# 12. Advanced technology features
# 13. Better fuel economy over time
# **Cons:**
# 1. Higher initial cost
# 2. Higher monthly payments
# 3. Possible higher insurance costs
# 4. Environmental impact of manufacturing a new car
#
# Total Pros: +50, Total Cons: -16 -> Score: **+34**
#
# ### Existing Car
# **Pros:**
# 1. Lower immediate cost
# 2. Lower insurance cost
# 3. Already paid off
# 4. Lower maintenance cost
# 5. More familiar to drive
# 6. Sentimental value
# 7. Lower total cost of ownership in short term
# 8. Lower depreciation rate
# 9. Lower carbon footprint from continued use
# 10. More cost-effective to maintain (assuming infrequent repairs)
# 11. More sustainable to operate with its current footprint
# **Cons:**
# 1. May require more frequent repairs in the future
# 2. Lacks advanced safety features and higher crash test ratings
# 3. Lower reliability rating
# 4. Older technology features
# 5. Higher environmental impact over long term due to lower fuel efficiency
#
# Total Pros: +42, Total Cons: -19 -> Score: **+23**
#
# ---
#
# ### Synoptic Analysis
#
# **Safety and Reliability** are paramount and strongly favor the **new car**.
#
# **Long-term cost** impact (depreciation, resale, and maintenance) also leans towards the new car.
#
# **Environmental impact** is mixed but slightly favors retaining the existing car short-term due to the manufacturing footprint of a new vehicle.
#
# ### Final Decision
#
# Considering the integrated analysis using both Dwight Eisenhower's and Ben Franklin's approaches:
#
# **FINAL DECISION:** Purchase a new car.
#
# This decision prioritizes safety, reliability, long-term financial benefits, and advanced features, which are critical factors for making a sound, future-proof choice.'
# # IS COMPLETE: True
