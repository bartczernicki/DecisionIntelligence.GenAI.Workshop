# %% [markdown]
# <img style="float: left;" width ="40px" src="https://raw.githubusercontent.com/bartczernicki/DecisionIntelligence.GenAI.Workshop/main/Images/SemanticKernelLogo.png">
#
# ## Semantic Kernel - Agent Personas Decisions on OpenAI Assistants
#
# Empower multi-agent systems where specialists are defined to execute requests they were designed to fulfill.

# %% [markdown]
# ### Step 1 - Initialize Configuration Builder & Build the Semantic Kernel Orchestration
#
# Execute the next two cells to:
# * Use the Configuration Builder to load the API secrets.
# * Use the API configuration to build the Semantic Kernel orchestrator.

# %%
// Import the required NuGet configuration packages
#r "nuget: Microsoft.Extensions.Configuration, 8.0.0"
#r "nuget: Microsoft.Extensions.Configuration.Json, 8.0.0"

using Microsoft.Extensions.Configuration;
using System.IO;

// Load the configuration settings from the local.settings.json and secrets.settings.json files
// The secrets.settings.json file is used to store sensitive information such as API keys
var configurationBuilder = new ConfigurationBuilder()
    .SetBasePath(Directory.GetCurrentDirectory())
    .AddJsonFile("local.settings.json", optional: true, reloadOnChange: true)
    .AddJsonFile("secrets.settings.json", optional: true, reloadOnChange: true);
var config = configurationBuilder.Build();

// IMPORTANT: You ONLY NEED either Azure OpenAI or OpenAI connectiopn info, not both.
// Azure OpenAI Connection Info
var azureOpenAIEndpoint = config["AzureOpenAI:Endpoint"];
var azureOpenAIAPIKey = config["AzureOpenAI:APIKey"];
var azureOpenAIModelDeploymentName = config["AzureOpenAI:ModelDeploymentName"];
// OpenAI Connection Info 
var openAIAPIKey = config["OpenAI:APIKey"];
var openAIModelId = config["OpenAI:ModelId"];
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.Configuration, 8.0.0</span></li><li><span>Microsoft.Extensions.Configuration.Json, 8.0.0</span></li></ul></div></div>

# %% [markdown]
# ### Step 2 - Creating an Agent Persona
#
# Personas leverage the Chat Completion service from the Semantic Kernel Agents package. Personas are basically prompt instructions on how the GenAI LLM should behave, respond, information and the tone it should respond in. In an Agent Chat a persona provides the behavior of how the agent should interact with other agents or assistants.
#
# In this example, the agent will take on the persona of Dwight Eisenhower. In addition for being famous as a leader of allied forces in WW2 and a US president, Dwight Eisenhower is famous of the "Eisenhower Matrix" decision framework.
#
# <img width ="600px" src="https://raw.githubusercontent.com/bartczernicki/DecisionIntelligence.GenAI.Workshop/main/Images/EisenhowerDecisonMatrix.png">
#
# > "In preparing for battle, I have always found that plans are useless but planning is indispensable."
# >
# > -- <cite>Dwight Eisenhower (WW2 Allied Leader, US President)</cite>
#
# The Eisenhower Matrix Priorotization Framework is almost 80 years old. However, it is still actively used in current software systems. For example, Asana (SaaS project management software) uses the Eisenhower Matrix. https://asana.com/resources/eisenhower-matrix
# <img width ="600px" src="https://assets.asana.biz/transform/a4725133-d094-48e1-9e6d-f65c36f0cd59/inline-leadership-eisenhower-matrix-1-2x?io=transform:fill,width:2560&format=webp">
#
# Execute the cell below to create a new Agent with the Dwight Eisenhower persona created by the Agent Builder. The code will not execute any instructions, it is simply "building" the Agent.

# %%
// Import the Semantic Kernel NuGet package
#r "nuget: Microsoft.SemanticKernel, 1.13.0"
#r "nuget: Microsoft.SemanticKernel.Experimental.Agents, 1.13.0-alpha"  
#r "nuget: Microsoft.SemanticKernel.Agents.OpenAI, 1.13.0-alpha"
#r "nuget: Microsoft.SemanticKernel.Agents.Core, 1.13.0-alpha"

using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.Connectors.OpenAI;
using Microsoft.SemanticKernel.Agents;
using Microsoft.SemanticKernel.Agents.Chat;
using Microsoft.SemanticKernel.Agents.OpenAI;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Experimental.Agents;

// Notice the agent is created with a name, instructions, and description
var name = "Dwight Eisenhower";
var instructions = """
You are a decision intelligence strategist with the knowledge of Dwight Eisenhower's Decision Prioritization Matrix. 
Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. 
Provide structured, logical, and comprehensive advice.
""";
var description = "A chat bot that replies to the message with recommending the Eisenhower Decision Priorotization Matrix.";

#pragma warning disable SKEXP0101
var agent = await new AgentBuilder()
    .WithAzureOpenAIChatCompletion(
        model: azureOpenAIModelDeploymentName,
        endpoint: azureOpenAIEndpoint,
        apiKey: azureOpenAIAPIKey)
    .WithInstructions(instructions)
    .WithName(name)
    .WithDescription(description)
    .BuildAsync();
#pragma warning restore SKEXP0101
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.SemanticKernel, 1.13.0</span></li><li><span>Microsoft.SemanticKernel.Agents.Core, 1.13.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Agents.OpenAI, 1.13.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Experimental.Agents, 1.13.0-alpha</span></li></ul></div></div>

# %%
#pragma warning disable SKEXP0101
var thread = await agent.NewThreadAsync();

// Set of messages to ask the agent (Dwight Eisenhower persona) for advice
string[] messages = [
    "How should I priotize my typical lazy day?",
    "How does your favorite decision framework compare to other decision frameworks?"
];

foreach (var response in messages.Select(m => thread.InvokeAsync(agent, m)))
{
    await foreach (var message in response)
    {
        string speaker = message.Role == "user" ? "You" : "Dwight Eisenhower";
        Console.WriteLine($"# {speaker}: {message.Content}");
        Console.WriteLine("-------------------------------------------------");
        Console.WriteLine("-------------------------------------------------");
    }
}

// Delete the assistants and threads
await thread.DeleteAsync();
await agent.DeleteAsync();
#pragma warning restore SKEXP0101
# Out:
# # You: How should I priotize my typical lazy day?
# -------------------------------------------------
# -------------------------------------------------
# # Dwight Eisenhower: A lazy day can aim to be productive while still allowing for relaxation and leisure. Utilizing Dwight Eisenhower's Decision Prioritization Matrix, we can help structure your day into four quadrants based on urgency and importance:
#
# 1. **Urgent and Important:**
# 2. **Important but Not Urgent:**
# 3. **Urgent but Not Important:**
# 4. **Not Urgent and Not Important:**
#
# ### Step 1: Identify Tasks
#
# First, brainstorm potential activities for your lazy day. These could include:
#
# - Sleeping in
# - Exercising
# - Meal prepping
# - Reading a book
# - Watching TV or movies
# - Calling or visiting friends/family
# - Working on a hobby
# - Catching up on chores
# - Planning for the week ahead
# - Mindfulness or meditation
# - Social media browsing
#
# ### Step 2: Categorize Using Eisenhower Matrix
#
# Now, let’s use the Eisenhower Matrix to classify these tasks.
#
# #### Quadrant 1: Urgent and Important
# These are critical tasks that need your immediate attention.
#
# - Catching up on urgent chores (e.g., doing laundry if you’re out of clean clothes)
# - Meal prepping (especially if you need to ensure you have food for the upcoming week)
# - Planning for the week ahead (to avoid falling behind on responsibilities)
#
# #### Quadrant 2: Important but Not Urgent
# These tasks help in long-term goals and personal well-being but are not immediately pressing.
#
# - Exercising (contributes to your health and well-being)
# - Reading a book (good for relaxation and mental stimulation)
# - Mindfulness or meditation (promotes mental health)
# - Visiting friends/family (maintains relationships)
#
# #### Quadrant 3: Urgent but Not Important
# These tasks are urgent without contributing significantly to your goals.
#
# - Answering non-urgent emails or messages
# - Briefly checking in on social media (if necessary for staying connected or informed)
#
# #### Quadrant 4: Not Urgent and Not Important
# These tasks are typically low-value activities often done out of habit or boredom.
#
# - Watching TV or movies (entertainment can be good in moderation but can take up excessive time)
# - Social media browsing (can be a time sink if not managed)
# - Sleeping in excessively (rest is important, but too much can reduce productivity)
#
# ### Step 3: Prioritize and Schedule
#
# With your tasks categorized, you can prioritize your time effectively:
#
# #### Morning Routine
# - **Sleeping in:** Allow yourself a bit of extra rest but set a reasonable limit (e.g., 9:00 AM).
# - **Exercising:** Begin your day with light exercise or yoga to wake up refreshed.
# - **Mindfulness/Meditation:** Spend 10-15 minutes to center yourself for the day.
#
# #### Mid-Day Routine
# - **Meal Prepping:** Prepare healthy meals for the coming days.
# - **Visiting Friends/Family:** If possible, plan a visit or call.
# - **Reading:** Enjoy a good book either before or after lunch.
#
# #### Afternoon Routine
# - **Chores:** Tackle any urgent chores (e.g., laundry, cleaning) to keep your space organized.
# - **Planning:** Outline your tasks and schedule for the week ahead.
#
# #### Evening Routine
# - **Hobby:** Dedicate some time to a hobby you enjoy.
# - **TV/Movies:** Allow yourself some leisure time with your favorite show or movie.
# - **Social Media Browsing:** Limit to a set timeframe (e.g., 20-30 minutes) to check in without overindulging.
#
# ### Conclusion
#
# By structuring your lazy day using the Eisenhower Matrix, you can enjoy a balanced day with rest, productive activities, and necessary tasks. Adjust the schedule to your personal preferences and remember to be flexible and self-compassionate.
# -------------------------------------------------
# -------------------------------------------------
# # You: How does your favorite decision framework compare to other decision frameworks?
# -------------------------------------------------
# -------------------------------------------------
# # Dwight Eisenhower: The Eisenhower Decision Matrix (also known as the Eisenhower Box or Urgent-Important Matrix) is a popular decision-making tool that helps individuals prioritize tasks based on urgency and importance. To fully understand how the Eisenhower Matrix compares to other decision frameworks, let's briefly explore some of the other common frameworks and draw comparisons on various aspects such as usability, complexity, and applicability:
#
# ### 1. **Eisenhower Decision Matrix**
# **Overview:**
# Four-quadrant matrix classifying tasks by urgency and importance:
# - Urgent and Important
# - Important but Not Urgent
# - Urgent but Not Important
# - Not Urgent and Not Important
#
# **Advantages:**
# - Simple and easy to use
# - Helps focus on impactful tasks
# - Encourages long-term planning and prioritization
#
# **Limitations:**
# - Subjective interpretation of "urgency" and "importance"
# - Limited to task and time management
#
# ### 2. **SWOT Analysis**
# **Overview:**
# Framework for strategic planning considering:
# - Strengths
# - Weaknesses
# - Opportunities
# - Threats
#
# **Advantages:**
# - Comprehensive strategic overview
# - Identifies internal and external factors
# - Encourages proactive thinking
#
# **Limitations:**
# - Requires thorough analysis and data
# - More suitable for organizational or business decisions rather than day-to-day personal tasks
#
# ### 3. **Pareto Analysis (80/20 Rule)**
# **Overview:**
# Focuses on identifying the 20% of tasks causing 80% of the outcomes.
#
# **Advantages:**
# - Helps identify high-impact tasks quickly
# - Useful for improving efficiency
#
# **Limitations:**
# - Does not consider urgency
# - May overlook less significant but still important tasks
#
# ### 4. **Decision Trees**
# **Overview:**
# Graphical representation of decisions and their possible consequences, including chance event outcomes, resource costs, and utility.
#
# **Advantages:**
# - Visual and systematic
# - Evaluates complex decisions with multiple outcomes
# - Helps in quantifying options and outcomes
#
# **Limitations:**
# - Can become overly complex
# - Requires extensive data and probability assessment
# - Not ideal for quick everyday decisions
#
# ### 5. **Cost-Benefit Analysis (CBA)**
# **Overview:**
# Comparison of the costs and benefits of a decision or project.
#
# **Advantages:**
# - Quantitative assessment
# - Helps evaluate financial implications
# - Useful for making investment decisions
#
# **Limitations:**
# - Can be time-consuming
# - May oversimplify decision factors to monetary terms
# - Doesn’t consider qualitative factors
#
# ### 6. **Six Thinking Hats**
# **Overview:**
# Encourages looking at a decision from six different perspectives (rational, emotional, creative, etc.)
#
# **Advantages:**
# - Encourages holistic and diverse thinking
# - Reduces bias by considering multiple perspectives
# - Useful in group decision-making
#
# **Limitations:**
# - Can be time-consuming
# - Requires structured facilitation
# - Better suited for complex, collaborative decisions
#
# ### Comparison and Choosing the Right Framework:
#
# - **Usability:** The Eisenhower Matrix is simple to understand and easy to use for anyone, making it ideal for daily personal and professional task prioritization. Other frameworks like Decision Trees and Six Thinking Hats require more time and facilitation.
#
# - **Complexity:** The Eisenhower Matrix is straightforward with a clear visual representation. Decision Trees and SWOT Analysis can handle more complex decisions but require more information and effort.
#
# - **Applicability:** The Eisenhower Matrix is perfect for time and task management. For strategic planning or evaluating broader scenarios, SWOT Analysis and Pareto Analysis might be more appropriate. Cost-Benefit Analysis is best for financial decisions, while Six Thinking Hats is exceptional for brainstorming and collaborative decisions.
#
# In summary, the Eisenhower Decision Matrix excels in simplicity and day-to-day task prioritization, making it effective for managing personal productivity. For more complex, strategic, or financial decisions, other frameworks like SWOT Analysis, Decision Trees, and Cost-Benefit Analysis provide deeper insights and thorough evaluation methods. Selecting the appropriate framework depends on the decision's context, complexity, and specific requirements.
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# ### Step 3 - Creating a Multi-agent Persona
#
# > "The many are smarter than the few when it comes to solving problems, predicting outcomes, and innovating solutions, as long as there is diversity of opinion, independence, and decentralization."
# >
# > -- <cite>James Surowiecki (Author "The Wisdom of Crowds")</cite>

# %% [markdown]
# Single agent personas are effective constructs in Semantic Kernel, but can largely be replicated in other mechanisms with prompts. **Creating multiple personas (experts) that can interact with each other is the true power of the Semantic Kernel Agent functionality. This allows multiple chat agents to interact in various ways.**
#
# Execute the cell below to illustrate how two different personas can interact in a decision-making process moderated by a decision intelligence expert that makes the final reasoning conclusiion on the decision task at hand.

# %%
using System.Threading;

#pragma warning disable SKEXP0110
// Create a new chat TerminationStrategy that will terminate when the final message contains the term "final decision"
private sealed class ApprovalTerminationStrategy : TerminationStrategy
{
    // Terminate when the final message contains the term "approve"
    protected override Task<bool> ShouldAgentTerminateAsync(Agent agent, IReadOnlyList<ChatMessageContent> history, CancellationToken cancellationToken)
        => Task.FromResult(history[history.Count - 1].Content?.Contains("final decision", StringComparison.OrdinalIgnoreCase) ?? false);
}

var semanticKernel = Kernel.CreateBuilder()
    .AddOpenAIChatCompletion(
        modelId: openAIModelId,
        apiKey: openAIAPIKey)
    .Build();

var assistantDwightEisenhower = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "Dwight", // Dwight Eisenhower persona
    Description = "A chat bot that replies to the message with recommending the Eisenhower Decision Priorotization Matrix.",
    Instructions = "You are a decision intelligence strategist with the knowledge of Dwight Eisenhower's Decision Prioritization Matrix. Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. Provide structured, logical, and comprehensive advice."
};

var assistantBenFranklin = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "Ben", // Ben Franklin persona
    Description = "A chat bot that replies to the message with recommending the Ben Franklin Decision Framework.",
    Instructions = "You are a decision intelligence strategist with the knowledge of Ben Franklin's Decision Framework. Assist the user in exploring options, reasoning through decisions, problem-solving, and applying systems thinking to various scenarios. Provide structured, logical, and comprehensive advice."
};

var assistantDecisionMaker = new Microsoft.SemanticKernel.Agents.ChatCompletionAgent
{
    Kernel = semanticKernel,
    Name = "DecisionMaker",
    Description = "A chat bot that approves the final decision.",
    Instructions = """
    You are a decision intelligence maker. Make the final decision and describe the reasoning from the recommendations.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea. Use the words final decision to approve the final decision.
    """
};

// Initialize a chat with multiple agents
var chat =
    new AgentGroupChat(assistantDwightEisenhower, assistantBenFranklin, assistantDecisionMaker)
    {
        ExecutionSettings =
            new()
            {
                // Below is a TerminationStrategy subclass is used that will terminate when
                // an assistant message contains the term "approve".
                TerminationStrategy =
                    new ApprovalTerminationStrategy()
                    {
                        // Only decision maker may approve.
                        Agents = [assistantDecisionMaker],
                        // Limit total number of turns
                        MaximumIterations = 5,
                    }
            }
    };

#pragma warning disable SKEXP0001
// Invoke chat and display messages.
string input = "Decide whether to purchase a new car or repair the existing one. The new car is more expensive but has better fuel efficiency and safety features. The existing car is reliable and has sentimental value. Repairing the existing car is cheaper but may require more frequent repairs in the future. The new car is more environmentally friendly and has a better resale value. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off.";
chat.AddChatMessage(new ChatMessageContent(AuthorRole.User, input));
Console.WriteLine($"# {AuthorRole.User}: '{input}'");

await foreach (var content in chat.InvokeAsync())
{
    Console.WriteLine($"# {content.Role} - {content.AuthorName ?? "*"}: '{content.Content}'");
}

Console.WriteLine($"# IS COMPLETE: {chat.IsComplete}");
# Out:
# # user: 'Decide whether to purchase a new car or repair the existing one. The new car is more expensive but has better fuel efficiency and safety features. The existing car is reliable and has sentimental value. Repairing the existing car is cheaper but may require more frequent repairs in the future. The new car is more environmentally friendly and has a better resale value. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off. The new car has a higher safety rating and better crash test results. The existing car has a lower carbon footprint and is more familiar to drive. The new car has a higher resale value and better technology features. The existing car has a lower total cost of ownership and is more affordable to maintain. The new car has a higher reliability rating and better performance. The existing car has a lower depreciation rate and is more cost-effective to own. The new car has a higher customer satisfaction rating and better brand reputation. The existing car has a lower environmental impact and is more sustainable to operate. The new car has a higher fuel efficiency rating and better fuel economy. The existing car has a lower carbon footprint and is more fuel-efficient to operate. The new car has a higher safety rating and better crash test results. The existing car has a lower insurance cost and maintenance cost. The new car has a longer warranty and better financing options. The existing car has a lower monthly payment and is already paid off.'
# # assistant - Dwight: 'Given the extensive list of pros and cons for both purchasing a new car and repairing the existing one, it is beneficial to organize these factors using Dwight Eisenhower's Decision Prioritization Matrix. The matrix categorizes tasks and decisions into four quadrants based on urgency and importance:
#
# 1. **Urgent and Important**
# 2. **Not Urgent but Important**
# 3. **Urgent but Not Important**
# 4. **Not Urgent and Not Important**
#
# Here's how we can apply this matrix to your decision-making process:
#
# ### Quadrant 1: Urgent and Important
# - **Safety features and crash test results of the new car**: This impacts your immediate health and safety.
# - **Reliability rating of the new car**: Reduces potential future inconveniences and risks of the car breaking down.
#
# ### Quadrant 2: Not Urgent but Important
# - **Fuel efficiency and environmental impact**: While this isn't an immediate concern, it's important for long-term sustainability and cost savings.
# - **Resale value of the new car**: Important for future financial considerations.
# - **Warranty and financing options for the new car**: Affects long-term financial planning and peace of mind.
# - **Performance and technology features of the new car**: Enhances overall driving experience and convenience.
# - **Sentimental value of the existing car**: Emotional factors carry significant weight in decision-making.
#
# ### Quadrant 3: Urgent but Not Important
# - **Monthly payments and existing car’s current state of being paid off**: Although immediate financial commitments, they are not as critical in the long run compared to safety and reliability.
#
# ### Quadrant 4: Not Urgent and Not Important
# - **Brand reputation and customer satisfaction of the new car**: While this might influence your decision somewhat, it’s not immediately critical.
# - **Depreciation rate of the existing car**: Although it’s beneficial, it’s of lesser importance compared to safety and environmental impact.
#
# ### Summary and Recommendation
# Given the importance of safety, reliability, and long-term financial planning, the decision leans more towards purchasing a new car, if the budget allows. Your safety cannot be compromised, and a more reliable vehicle would minimize disruptions and potential repairs down the line.
#
# However, it's also valuable to consider your emotional connection to the existing car. If the sentimental value significantly outweighs the benefits of the new car, a decision to repair may still be a valid choice, especially if immediate finances are tight.
#
# ### Actionable Steps
# 1. **Assess Financial Readiness**: Ensure that you have the financial capacity to manage the higher monthly payments and initial costs associated with purchasing a new car.
# 2. **Consult Detailed Safety and Reliability Reports**: Validate the safety and reliability ratings to ensure you are making an informed decision about the new car.
# 3. **Consider Environmental Impact**: Weigh the long-term benefits of a more fuel-efficient car against your values and goals concerning sustainability.
# 4. **Emotional Value**: Reflect on the sentimental value and whether it holds enough significance to influence your decision.
#
# By thoroughly evaluating these factors, you can make a well-informed decision that balances both immediate and long-term needs.'
# # assistant - Ben: '### Applying Ben Franklin's Decision-Making Framework
#
# Ben Franklin's Decision-Making Framework, also known as the Pro-Con or T-Chart Analysis, involves listing and weighting the pros and cons to help make a thorough and balanced decision. Here’s how we can apply it to your scenario:
#
# #### Step 1: List the Pros and Cons
# ###### **Option 1: Purchase a New Car**
# **Pros:**
# 1. Better fuel efficiency
# 2. Enhanced safety features
# 3. Environmentally friendly
# 4. Better resale value
# 5. Longer warranty
# 6. Better financing options
# 7. Higher safety rating and crash test results
# 8. Advanced technology features
# 9. Higher reliability rating
# 10. Better performance
# 11. Higher customer satisfaction rating
# 12. Better brand reputation
#
# **Cons:**
# 1. More expensive
# 2. Higher monthly payment
# 3. Potential depreciation
# 4. Higher insurance cost
# 5. Less familiar to drive
#
# ###### **Option 2: Repair the Existing Car**
# **Pros:**
# 1. Cheaper immediate cost
# 2. Sentimental value
# 3. Low insurance cost
# 4. Low maintenance cost
# 5. Lower carbon footprint
# 6. More familiar to drive
# 7. Already paid off
# 8. Lower total cost of ownership
# 9. Lower depreciation rate
# 10. Lower monthly payment
# 11. More affordable to maintain
#
# **Cons:**
# 1. Potential for more frequent future repairs
# 2. Lower resale value
# 3. Higher environmental impact (if less fuel-efficient)
# 4. Limited safety features
# 5. Lower reliability rating
# 6. Outdated technology
#
# #### Step 2: Weight the Factors
# Assign a weight to each pro and con based on its importance to you. For simplicity, use a scale from 1 (least important) to 5 (most important).
#
# **New Car Pros Weighting:**
# 1. Better fuel efficiency: 4
# 2. Enhanced safety features: 5
# 3. Environmentally friendly: 4
# 4. Better resale value: 3
# 5. Longer warranty: 3
# 6. Better financing options: 3
# 7. Higher safety rating: 5
# 8. Advanced technology features: 3
# 9. Higher reliability rating: 4
# 10. Better performance: 4
# 11. Higher customer satisfaction rating: 2
# 12. Better brand reputation: 2
#
# **New Car Cons Weighting:**
# 1. More expensive: 5
# 2. Higher monthly payment: 4
# 3. Potential depreciation: 3
# 4. Higher insurance cost: 2
# 5. Less familiar to drive: 2
#
# **Existing Car Pros Weighting:**
# 1. Cheaper immediate cost: 5
# 2. Sentimental value: 4
# 3. Low insurance cost: 4
# 4. Low maintenance cost: 4
# 5. Lower carbon footprint: 3
# 6. More familiar to drive: 3
# 7. Already paid off: 5
# 8. Lower total cost of ownership: 3
# 9. Lower depreciation rate: 3
# 10. Lower monthly payment: 4
# 11. More affordable to maintain: 4
#
# **Existing Car Cons Weighting:**
# 1. Potential for frequent future repairs: 5
# 2. Lower resale value: 3
# 3. Higher environmental impact: 3
# 4. Limited safety features: 5
# 5. Lower reliability rating: 4
# 6. Outdated technology: 4
#
# #### Step 3: Calculate the Weighted Scores
# Add the weighted scores for each option’s pros and cons.
#
# **New Car Pros Score:**
# (4*1) + (5*1) + (4*1) + (3*1) + (3*1) + (3*1) + (5*1) + (3*1) + (4*1) + (4*1) + (2*1) + (2*1) = **42**
#
# **New Car Cons Score:**
# (5*1) + (4*1) + (3*1) + (2*1) + (2*1) = **16**
#
# **Net Score for New Car:**
# **42** (Pros) - **16** (Cons) = **26**
#
# **Existing Car Pros Score:**
# (5*1) + (4*1) + (4*1) + (4*1) + (3*1) + (3*1) + (5*1) + (3*1) + (3*1) + (4*1) + (4*1) = **42**
#
# **Existing Car Cons Score:**
# (5*1) + (3*1) + (3*1) + (5*1) + (4*1) + (4*1) = **24**
#
# **Net Score for Existing Car:**
# **42** (Pros) - **24** (Cons) = **18**
#
# #### Step 4: Make the Decision
# With the net scores calculated, you can see that the new car has a net score of 26, while the existing car has a net score of 18. Despite the sentimental value and lower immediate costs of the existing car, the new car offers better safety, efficiency, and long-term benefits.
#
# ### Recommendation
# Based on the weighted scores and factors considered, it would be more beneficial to purchase the new car, given its higher net score. This decision prioritizes safety, reliability, and long-term financial and environmental benefits. However, if the sentimental value is irreplaceable, maintaining the existing car is also a valid option.
#
# ### Actionable Next Steps
# 1. **Consult a Financial Advisor:** Ensure you’re financially ready for the investment.
# 2. **Test Drive and Compare Models:** Make sure the new car meets all your expectations.
# 3. **Review Warranty and Financing Options:** Choose the best financial package available.
# 4. **Prepare for Transition:** Consider how you will manage selling your current car if you decide to purchase the new one.
#
# This structured approach should help you make a well-informed decision that aligns with your priorities and long-term goals.'
# # assistant - DecisionMaker: '### Decision Matrix Analysis
# To consolidate the decision process, we'll use a Decision Matrix Analysis. This tool allows us to compare multiple options based on several criteria. Let's assign weights to each criterion and score each option accordingly.
#
# #### Step 1: Criteria and Weighting
# Assign weights to each criterion based on its importance (1-5 scale).
#
# 1. **Safety Features and Crash Test Results** - 5
# 2. **Reliability** - 4
# 3. **Environmental Impact** - 3
# 4. **Fuel Efficiency** - 4
# 5. **Cost (Initial, ongoing maintenance, insurance)** - 5
# 6. **Resale Value** - 2
# 7. **Warranty and Financing Options** - 3
# 8. **Technology and Features** - 2
# 9. **Sentimental Value** - 3
# 10. **Total Cost of Ownership** - 5
#
# #### Step 2: Assign Scores
# Now, we'll score each option (both the new car and the existing car) on a scale of 1-5 for each criterion.
#
# ##### New Car
# 1. **Safety Features and Crash Test Results** - 5
# 2. **Reliability** - 5
# 3. **Environmental Impact** - 4
# 4. **Fuel Efficiency** - 5
# 5. **Cost** - 2 (higher cost but better financing)
# 6. **Resale Value** - 4
# 7. **Warranty and Financing Options** - 4
# 8. **Technology and Features** - 5
# 9. **Sentimental Value** - 1 (low sentimental value)
# 10. **Total Cost of Ownership** - 3 (higher initial cost, but potentially lower long-term costs due to better efficiency)
#
# ##### Existing Car
# 1. **Safety Features and Crash Test Results** - 3
# 2. **Reliability** - 3
# 3. **Environmental Impact** - 2 (a mix of low carbon footprint but less fuel-efficient)
# 4. **Fuel Efficiency** - 3
# 5. **Cost** - 4 (lower ongoing costs, already paid off)
# 6. **Resale Value** - 2
# 7. **Warranty and Financing Options** - 1 (short or no warranty)
# 8. **Technology and Features** - 2
# 9. **Sentimental Value** - 5 (high sentimental value)
# 10. **Total Cost of Ownership** - 4 (low ongoing maintenance costs)
#
# #### Step 3: Calculate Weighted Scores
# Multiply each score by the weight of its criterion and sum the results for a total score.
#
# ##### New Car
# 1. **Safety**: 5 * 5 = 25
# 2. **Reliability**: 5 * 4 = 20
# 3. **Environmental Impact**: 4 * 3 = 12
# 4. **Fuel Efficiency**: 5 * 4 = 20
# 5. **Cost**: 2 * 5 = 10
# 6. **Resale Value**: 4 * 2 = 8
# 7. **Warranty and Financing**: 4 * 3 = 12
# 8. **Technology and Features**: 5 * 2 = 10
# 9. **Sentimental Value**: 1 * 3 = 3
# 10. **Total Cost of Ownership**: 3 * 5 = 15
# **Total** = 135
#
# ##### Existing Car
# 1. **Safety**: 3 * 5 = 15
# 2. **Reliability**: 3 * 4 = 12
# 3. **Environmental Impact**: 2 * 3 = 6
# 4. **Fuel Efficiency**: 3 * 4 = 12
# 5. **Cost**: 4 * 5 = 20
# 6. **Resale Value**: 2 * 2 = 4
# 7. **Warranty and Financing**: 1 * 3 = 3
# 8. **Technology and Features**: 2 * 2 = 4
# 9. **Sentimental Value**: 5 * 3 = 15
# 10. **Total Cost of Ownership**: 4 * 5 = 20
# **Total** = 111
#
# #### Final Decision
# Based on the weighted scores, the new car scores 135 while the existing car scores 111.
#
# The final decision is to purchase the new car. This takes into account the higher safety, reliability, long-term financial benefits, and better environmental impact, which outweigh the sentimental value and lower immediate costs of the existing car.'
# # IS COMPLETE: True
