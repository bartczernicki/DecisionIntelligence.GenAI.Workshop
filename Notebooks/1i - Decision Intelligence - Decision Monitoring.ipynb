# %% [markdown]
# <div style="display: flex; align-items: center;">
#   <img src="../Images/Logos/DecisionIntelligenceLogo.png" width="60px" style="margin-right: 10px;">
#   <span style="font-size: 1.5em; font-weight: bold;">Decision Intelligence – Decision Monitoring</span>
# </div>

# %% [markdown]
# <img style="display: block; margin: auto;" width ="700px" src="../Images/DecisionIntelligence-DecisionCommunication.png">
